# %% [markdown]
# <div align="left" style="background-color: #008080; padding: 20px 10px;">
# <h3><b>IDEAS - Institute of Data Engineering, Analytics and Science Foundation</b></h3>
# <p>Summer Internship Program 2026</p>
# <hr style="width:100%;">
# <h3><b>Project Title:</b> Exploratory Data Analysis with EPC Industry Data</h3>
# <h4>Project Notebook</h4>
#
# <blockquote style="border-left: 4px solid #4285F4; padding-left: 15px;">
#   <strong>Created by:</strong> Koulika Paul<br>
#   <strong>Designation:</strong> Project Linked Associate Research Engineer in Statistics<br>
# </blockquote>
# <hr style="width:100%;">
# </div>

# %% [markdown]
# ### Question 1: Load Dataset and Basic Exploration (1 Mark)
#
# Import `pandas` as `pd` and `numpy` as `np`. Download the dataset `EPC_Industry_Analytics_Demo.xlsx` from https://drive.google.com/drive/folders/1gieHICVDBbUKMZiSF4YRQMAJic-w50JM?usp=sharing. Load the dataset `EPC_Industry_Analytics_Demo.xlsx` into a DataFrame named `df`.
#
# Print the shape of the dataset, its data types, and the count of missing values for each column.
#
# **Expected Output:** The shape tuple, the data types of columns, and the sum of missing values per column.

# %%
# Write your answer here
import pandas as pd
import numpy as np

# Load the dataset into a DataFrame named df
df = pd.read_excel('EPC_Industry_Analytics_Demo.xlsx')

# Basic Exploration
print("Shape:", df.shape)
print("\nData Types:\n", df.dtypes)
print("\nMissing Values:\n", df.isnull().sum())
# Out:
# Shape: (1200, 14)
#
# Data Types:
#  Date                     datetime64[ns]
# Project_ID                       object
# Region                           object
# Project_Type                     object
# Contractor_Tier                  object
# Planned_Budget_K                float64
# Actual_Cost_K                   float64
# Budget_Variance_Pct             float64
# Sensor_Vibration_mm_s           float64
# Sensor_Temp_C                   float64
# Efficiency_Score                float64
# Material_Price_Index            float64
# Unnamed: 12                     float64
# Unnamed: 13                      object
# dtype: object
#
# Missing Values:
#  Date                        0
# Project_ID                  0
# Region                      0
# Project_Type                0
# Contractor_Tier            60
# Planned_Budget_K            0
# Actual_Cost_K               0
# Budget_Variance_Pct         0
# Sensor_Vibration_mm_s       0
# Sensor_Temp_C               0
# Efficiency_Score            0
# Material_Price_Index        0
# Unnamed: 12              1200
# Unnamed: 13              1199
# dtype: int64

# %% [markdown]
# ### Question 2: Duplicate Record Analysis (1 Mark)
#
# Find the duplicate rows in the DataFrame `df` and print the total number of duplicate rows.
#
# **Expected Output:** A print statement showing the count of duplicate rows.

# %%
# Write your answer here
# Count duplicate rows (Source: [2])
total_duplicates = df.duplicated().sum()
print(f"Total number of duplicate rows: {total_duplicates}")
# Out:
# Total number of duplicate rows: 0

# %% [markdown]
# ### Question 3: Missing Value Treatment (2 Marks)
#
# First, replace any occurrences of blank spaces `' '`, empty strings `''`, `'None'`, and `'-'` with `np.nan` across the entire DataFrame.
# Next, fill the missing values in all **numeric columns** with the median of their respective columns.
# Finally, print the first 5 rows of the DataFrame to verify the changes.
#
# **Expected Output:** A table showing the first 5 rows of the modified DataFrame.

# %%
# Write your answer here
# Replace specific strings with np.nan (Source: [3])
df.replace([' ', '', 'None', '-'], np.nan, inplace=True)

# Identify numeric columns and fill with median (Source: [3])
numeric_cols = df.select_dtypes(include=[np.number]).columns
df[numeric_cols] = df[numeric_cols].fillna(df[numeric_cols].median())

# Verify changes (Source: [3])
print(df.head())
# Out:
#         Date Project_ID         Region      Project_Type Contractor_Tier  \
# 0 2023-01-01  PROJ-1000  North America  Renewable Energy          Tier 3
# 1 2023-01-01  PROJ-1001          LATAM  Industrial Plant          Tier 1
# 2 2023-01-01  PROJ-1002           APAC         Oil & Gas          Tier 1
# 3 2023-01-01  PROJ-1003  North America  Industrial Plant          Tier 2
# 4 2023-01-02  PROJ-1004  North America  Renewable Energy          Tier 2
#
#    Planned_Budget_K  Actual_Cost_K  Budget_Variance_Pct  \
# 0       2032.718750    2095.845956             3.105555
# 1        822.703500     839.771030             2.074566
# 2       2343.330027    2501.768017             6.761232
# 3       1900.478728    1966.592256             3.478783
# 4       3547.042879    3508.019596            -1.100164
#
#    Sensor_Vibration_mm_s  Sensor_Temp_C  Efficiency_Score  \
# 0               4.775256      63.900729         64.144031
# 1               1.779238      46.502858         83.031245
# 2               2.303336      50.985558         81.513558
# 3               3.341599      59.448200         72.523566
# 4               3.501433      59.905765         70.703579
#
#    Material_Price_Index  Unnamed: 12 Unnamed: 13
# 0            100.000000          NaN         NaN
# 1            100.058382          NaN         NaN
# 2            100.116760          NaN         NaN
# 3            100.175133          NaN         NaN
# 4            100.233497          NaN         NaN

# %% [markdown]
# ### Question 4: Statistical Summary (1 Mark)
#
# Generate and display a complete statistical summary of the DataFrame `df`, including all columns (both numeric and categorical).
#
# **Hint:** Use the `.describe(include='all')` method.
#
# **Expected Output:** A comprehensive statistical summary table.

# %%
# Write your answer here
# Complete summary for all columns (Source: [4])
print(df.describe(include='all'))
# Out:
#                        Date Project_ID Region      Project_Type  \
# count                  1200       1200   1200              1200
# unique                  NaN       1200      4                 4
# top                     NaN  PROJ-2183  LATAM  Renewable Energy
# freq                    NaN          1    317               314
# mean    2023-05-30 12:00:00        NaN    NaN               NaN
# min     2023-01-01 00:00:00        NaN    NaN               NaN
# 25%     2023-03-16 18:00:00        NaN    NaN               NaN
# 50%     2023-05-30 12:00:00        NaN    NaN               NaN
# 75%     2023-08-13 06:00:00        NaN    NaN               NaN
# max     2023-10-27 00:00:00        NaN    NaN               NaN
# std                     NaN        NaN    NaN               NaN
#
#        Contractor_Tier  Planned_Budget_K  Actual_Cost_K  Budget_Variance_Pct  \
# count             1140       1200.000000    1200.000000          1200.000000
# unique               3               NaN            NaN                  NaN
# top             Tier 2               NaN            NaN                  NaN
# freq               574               NaN            NaN                  NaN
# mean               NaN       2750.430575    2987.503387             8.482366
# min                NaN        500.052356     508.320284           -12.012275
# 25%                NaN       1650.494262    1801.340050             3.374540
# 50%                NaN       2751.711332    2967.673642             8.426896
# 75%                NaN       3875.982343    4201.870148            13.529789
# max                NaN       4995.016754    6264.832318            29.201684
# std                NaN       1298.446505    1431.969622             7.294449
#
#         Sensor_Vibration_mm_s  Sensor_Temp_C  Efficiency_Score  \
# count             1200.000000    1200.000000       1200.000000
# unique                    NaN            NaN               NaN
# top                       NaN            NaN               NaN
# freq                      NaN            NaN               NaN
# mean                 3.131770      54.708580         76.433536
# min                  0.045447      36.325602          0.000000
# 25%                  1.462936      47.091556         68.160112
# 50%                  2.473560      52.401493         80.128976
# 75%                  4.062142      60.197818         88.481085
# max                 25.000000     112.475349        100.000000
# std                  2.868782      10.514297         16.656041
#
#         Material_Price_Index  Unnamed: 12 Unnamed: 13
# count            1200.000000          0.0           1
# unique                   NaN          NaN           1
# top                      NaN          NaN
# freq                     NaN          NaN           1
# mean              110.917631          NaN         NaN
# min               100.000000          NaN         NaN
# 25%               105.460036          NaN         NaN
# 50%               108.313578          NaN         NaN
# 75%               118.146958          NaN         NaN
# max               121.113572          NaN         NaN
# std                 6.464250          NaN         NaN

# %% [markdown]
# ### Question 5: Correlation Analysis (2 Marks)
#
# Calculate the correlation matrix for all numeric columns in the DataFrame `df` and print the resulting matrix.
#
# **Hint:** Select numeric columns first using `.select_dtypes(include=np.number)`, then apply `.corr()`.
#
# **Expected Output:** A correlation matrix showing the linear relationship between numeric features.

# %%
# Write your answer here
# Select numeric columns and calculate correlation (Source: [5])
numeric_df = df.select_dtypes(include=np.number)
correlation_matrix = numeric_df.corr()
print(correlation_matrix)
# Out:
#                        Planned_Budget_K  Actual_Cost_K  Budget_Variance_Pct  \
# Planned_Budget_K               1.000000       0.987637             0.039850
# Actual_Cost_K                  0.987637       1.000000             0.181439
# Budget_Variance_Pct            0.039850       0.181439             1.000000
# Sensor_Vibration_mm_s          0.047613       0.048364             0.016270
# Sensor_Temp_C                 -0.006899      -0.010928            -0.006320
# Efficiency_Score               0.019985       0.023992             0.006594
# Material_Price_Index          -0.000661      -0.007159            -0.035049
# Unnamed: 12                         NaN            NaN                  NaN
#
#                        Sensor_Vibration_mm_s  Sensor_Temp_C  Efficiency_Score  \
# Planned_Budget_K                    0.047613      -0.006899          0.019985
# Actual_Cost_K                       0.048364      -0.010928          0.023992
# Budget_Variance_Pct                 0.016270      -0.006320          0.006594
# Sensor_Vibration_mm_s               1.000000       0.707830         -0.697970
# Sensor_Temp_C                       0.707830       1.000000         -0.963516
# Efficiency_Score                   -0.697970      -0.963516          1.000000
# Material_Price_Index                0.013068       0.021116         -0.012720
# Unnamed: 12                              NaN            NaN               NaN
#
#                        Material_Price_Index  Unnamed: 12
# Planned_Budget_K                  -0.000661          NaN
# Actual_Cost_K                     -0.007159          NaN
# Budget_Variance_Pct               -0.035049          NaN
# Sensor_Vibration_mm_s              0.013068          NaN
# Sensor_Temp_C                      0.021116          NaN
# Efficiency_Score                  -0.012720          NaN
# Material_Price_Index               1.000000          NaN
# Unnamed: 12                             NaN          NaN

# %% [markdown]
# ### Question 6: Outlier Detection using IQR (3 Marks)
#
# Write a loop to calculate the Interquartile Range (IQR) for each numeric column in `df`.
# Define outliers as values below `Q1 - 1.5 * IQR` or above `Q3 + 1.5 * IQR`.
# Count the number of outliers for each numeric column and store them in a dictionary named `outlier_summary`. Print this dictionary.
#
# **Expected Output:** A dictionary showing the column names as keys and their respective outlier counts as values.

# %%
# Write your answer here
# Calculate outliers for each numeric column (Source: [6])
outlier_summary = {}
numeric_cols = df.select_dtypes(include=np.number).columns

for col in numeric_cols:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    # Count rows outside bounds
    count = df[(df[col] < lower_bound) | (df[col] > upper_bound)].shape
    outlier_summary[col] = count

print(outlier_summary)
# Out:
# {'Planned_Budget_K': (0, 14), 'Actual_Cost_K': (0, 14), 'Budget_Variance_Pct': (3, 14), 'Sensor_Vibration_mm_s': (41, 14), 'Sensor_Temp_C': (32, 14), 'Efficiency_Score': (33, 14), 'Material_Price_Index': (0, 14), 'Unnamed: 12': (0, 14)}

# %% [markdown]
# ### Question 7: Group-Based Aggregation (2 Marks)
#
# Select the first categorical (object) column in the DataFrame. Group the data by this categorical column and calculate the `mean`, `median`, and `sum` for all numeric columns.
# Display the first 5 rows of the aggregated results.
#
# **Hint:** Use `.groupby()` combined with `.agg(['mean', 'median', 'sum'])`.
#
# **Expected Output:** A table showing the first 5 rows of grouped statistical aggregations.

# %%
# Write your answer here
cat_cols = df.select_dtypes(include=['object']).columns

first_cat_col_name = cat_cols[0]   # <-- pick the first column name

numeric_cols = df.select_dtypes(include=[np.number]).columns

aggregated = df.groupby(first_cat_col_name)[numeric_cols].agg(['mean', 'median', 'sum'])

print(aggregated.head())
# Out:
#            Planned_Budget_K                           Actual_Cost_K  \
#                        mean       median          sum          mean
# Project_ID
# PROJ-1000       2032.718750  2032.718750  2032.718750   2095.845956
# PROJ-1001        822.703500   822.703500   822.703500    839.771030
# PROJ-1002       2343.330027  2343.330027  2343.330027   2501.768017
# PROJ-1003       1900.478728  1900.478728  1900.478728   1966.592256
# PROJ-1004       3547.042879  3547.042879  3547.042879   3508.019596
#
#                                      Budget_Variance_Pct                      \
#                  median          sum                mean    median       sum
# Project_ID
# PROJ-1000   2095.845956  2095.845956            3.105555  3.105555  3.105555
# PROJ-1001    839.771030   839.771030            2.074566  2.074566  2.074566
# PROJ-1002   2501.768017  2501.768017            6.761232  6.761232  6.761232
# PROJ-1003   1966.592256  1966.592256            3.478783  3.478783  3.478783
# PROJ-1004   3508.019596  3508.019596           -1.100164 -1.100164 -1.100164
#
#            Sensor_Vibration_mm_s  ... Sensor_Temp_C Efficiency_Score  \
#                             mean  ...           sum             mean
# Project_ID                        ...
# PROJ-1000               4.775256  ...     63.900729        64.144031
# PROJ-1001               1.779238  ...     46.502858        83.031245
# PROJ-1002               2.303336  ...     50.985558        81.513558
# PROJ-1003               3.341599  ...     59.448200        72.523566
# PROJ-1004               3.501433  ...     59.905765        70.703579
#
#                                  Material_Price_Index                          \
#                median        sum                 mean      median         sum
# Project_ID
# PROJ-1000   64.144031  64.144031           100.000000  100.000000  100.000000
# PROJ-1001   83.031245  83.031245           100.058382  100.058382  100.058382
# PROJ-1002   81.513558  81.513558           100.116760  100.116760  100.116760
# PROJ-1003   72.523566  72.523566           100.175133  100.175133  100.175133
# PROJ-1004   70.703579  70.703579           100.233497  100.233497  100.233497
#
#            Unnamed: 12
#                   mean median  sum
# Project_ID
# PROJ-1000          NaN    NaN  0.0
# PROJ-1001          NaN    NaN  0.0
# PROJ-1002          NaN    NaN  0.0
# PROJ-1003          NaN    NaN  0.0
# PROJ-1004          NaN    NaN  0.0
#
# [5 rows x 24 columns]

# %% [markdown]
# ### Question 8: Feature Engineering (2 Marks)
#
# Identify the first two numeric columns in the DataFrame. Create a new feature named `New_Feature` by dividing the first numeric column by the (second numeric column + 1).
# Display the first 5 rows of the DataFrame showing this new feature.
#
# **Expected Output:** The first 5 rows of the DataFrame containing the newly engineered `New_Feature` column.

# %%
# Write your answer here
num_cols = df.select_dtypes(include=np.number).columns

df['New_Feature'] = df[num_cols[0]] / (df[num_cols[1]] + 1)

print(df[[num_cols[0], num_cols[1], 'New_Feature']].head())
# Out:
#    Planned_Budget_K  Actual_Cost_K  New_Feature
# 0       2032.718750    2095.845956     0.969417
# 1        822.703500     839.771030     0.978511
# 2       2343.330027    2501.768017     0.936295
# 3       1900.478728    1966.592256     0.965891
# 4       3547.042879    3508.019596     1.010836

# %% [markdown]
# ### Question 9: Ranking Analysis (2 Marks)
#
# Select the first numeric column in your DataFrame. Create a new column called `Rank` which assigns a rank to each row based on the values in this first numeric column in **descending order** (highest value gets rank 1).
# Display the first 5 rows of the DataFrame showing only the `Rank` column and the first numeric column.
#
# **Hint:** Use the `.rank(ascending=False)` method.
#
# **Expected Output:** The first 5 rows of the `Rank` column alongside the target numeric column.

# %%
# Write your answer here
first_num_col = df.select_dtypes(include=np.number).columns[0]

df['Rank'] = df[first_num_col].rank(ascending=False)

print(df[[first_num_col, 'Rank']].head())
# Out:
#    Planned_Budget_K    Rank
# 0       2032.718750   791.0
# 1        822.703500  1104.0
# 2       2343.330027   702.0
# 3       1900.478728   823.0
# 4       3547.042879   390.0

# %% [markdown]
# ### Question 10: Conditional Filtering (1 Mark)
#
# Using the first numeric column again, filter the DataFrame `df` to include only those rows where the value in this column is strictly **greater than its mean**.
# Print the shape of this new conditionally filtered DataFrame.
#
# **Expected Output:** A tuple showing the number of rows and columns in the filtered DataFrame.

# %%
# Write your answer here
first_num_col = df.select_dtypes(include=np.number).columns
filtered_df = df[df[first_num_col] > df[first_num_col].mean()]
print("Filtered Shape:", filtered_df.shape)
# Out:
# Filtered Shape: (1200, 16)

# %% [markdown]
# ### Question 11: Load MNIST Data (3 Marks)
#
# Load the MNIST dataset using `sklearn.datasets.load_digits`. Separate the dataset into features (`X`) and target labels (`y`).
# Print the shape of the features and the target arrays.
#
# **Expected Output:** The shape of `X` and `y`.

# %%
# Write your answer here
from sklearn.datasets import load_digits
digits = load_digits()
X = digits.data
y = digits.target
print("X shape:", X.shape, "y shape:", y.shape)
# Out:
# X shape: (1797, 64) y shape: (1797,)

# %% [markdown]
# ### Question 12: K-Means Clustering (5 Marks)
#
# Import `KMeans` from `sklearn.cluster`. Initialize and fit the K-Means clustering model on the MNIST features (`X`).
# Since we know there are 10 digits (0-9), set the number of clusters to 10. Assign the cluster labels to a variable `kmeans_labels`.
#
# **Expected Output:** A successfully fitted K-Means model and the cluster labels array.

# %%
# Write your answer here
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=10, random_state=42)
kmeans.fit(X)
kmeans_labels = kmeans.labels_

# %% [markdown]
# ### Question 13: F1 Score Evaluation for Clustering (5 Marks)
#
# Evaluate the clustering performance using the F1 score. Since K-Means assigns arbitrary cluster labels, you will first need to map each cluster label to the most frequent true label in that cluster.
# After mapping the labels, calculate and print the macro-averaged F1 score using `sklearn.metrics.f1_score`.
#
# **Expected Output:** The calculated F1 score of the clustering.

# %%
# Write your answer here
from sklearn.metrics import f1_score
from scipy.stats import mode
import numpy as np

# Mapping cluster labels to true labels
mapped_labels = np.zeros_like(kmeans_labels)

for i in range(10):
    mask = (kmeans_labels == i)

    if np.sum(mask) > 0:  # avoid empty clusters
        mapped_labels[mask] = mode(y[mask], keepdims=False).mode

# Macro-averaged F1 score
f1 = f1_score(y, mapped_labels, average='macro')
print("Macro F1 Score:", f1)
# Out:
# Macro F1 Score: 0.8627854786352394
